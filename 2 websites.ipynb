# %% [markdown]
# ## Shri Ramdeobaba College of Engineering and Management , Nagpur
# ### Python Group Project : Group 7
# ### Program to Check Plagirism
# #### Group members
# ##### E-29 , Amaan Khan
# ##### E-34 , Bipul Biswas
# ##### E-35 , Chaitanya Murarka

# %%
from googlesearch import search
import requests
from bs4 import BeautifulSoup
import urllib.request, urllib.error, urllib.parse
from urllib import request

# %%
# Getting URl to Process
# Refered : https://docs.google.com/document/d/e/2PACX-1vSJLCQ0NCFsy5di5oR5deO8L_hnWLpcwN0IlDrFfqMLwawMrn-wH5KUVaKHemW80b_UGudFJyK6mXw9/pub
query = input("Enter the string you want to check : ")
my_results_list = []
for i in search(query,        # The query you want to run
                tld = 'com',  # The top level domain
                lang = 'en',  # The language
                num = 1,      # Number of results per page
                start = 0,    # First result to retrieve
                stop = 2,     # Last result to retrieve
                #pause = 2.0,  Lapse between HTTP requests
               ):
    my_results_list.append(i)
    print("Matching Website",)
    print(i)
# Out:
# Enter the string you want to check : MH03DG1289
# Matching Website
# https://transport.maharashtra.gov.in/site/upload/pdf/Oct18%20Fitness%20done%20in%20MH.pdf
# Matching Website
# https://www.drivespark.com/rto-vehicle-registration-details/maharashtra-mh-03/

# %%
result1=my_results_list[0]
result2=my_results_list[1]

# %%
# Code to extract html

url1 = result1

file1 = urllib.request.urlopen(url1)

for line in file1:
    webpage = line.decode("utf-8")
    print(webpage)
# Out:
# %PDF-1.7
#
#
#
# 4 0 obj
#
# (Identity)
#
# endobj
#
# 5 0 obj
#
# (Adobe)
#
# endobj
#
# 8 0 obj
#
# <<
#
# /Filter /FlateDecode
#
# /Length 100843
#
# /Type /Stream
#
# >>
#
# stream
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9832/1481698575.py in <module>
#       6
#       7 for line in file1:
# ----> 8     webpage = line.decode("utf-8")
#       9     print(webpage)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9c in position 1: invalid start byte

# %%
url2 = result2

file2 = urllib.request.urlopen(url2)

for line in file2:
    webpage2 = line.decode("utf-8")
    print(webpage2)

# %%
# Converting to text

# Initializing variable

txt1 = BeautifulSoup(request.urlopen(result1).read())
txt2 = BeautifulSoup(request.urlopen(result2).read())


# Calculating result
res1 = txt1.get_text()
res2 = txt2.get_text()


# Printing the result
print("Text Format of Result 1",res1)
print("Text Format of Result 2",res2)
# Out:
# Text Format of Result 1 %PDF-1.7
#
# 4 0 obj
# (Identity)
# endobj
# 5 0 obj
# (Adobe)
# endobj
# 8 0 obj
# <<
# Text Format of Result 2
#
#
#
#
# MH-03 Mumbai (East) - Ghatkopar RTO Vehicle Registration Details - DriveSpark
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Drivespark Database
#
#
#
#
#
#
#
#
#  ENGLISH arrow_drop_down
#
#
#
#
#
#
#
#
#
#
#
#  Get Google Chrome Extension
#
# Extension
# extension
#
#
#
# Notifications
#
# notifications
#
#
# Notifications
# notifications_off
#
#
#
#
#
# Manage your notification subscription by clicking on the icon.
#
#
#
#
#
# To start receiving timely alerts, as shown below click on the Green “lock” icon next to the address bar
#  Click it and Unblock the Notifications
# Close X
#
#
#
#
# Close X
#
# To Start receiving timely alerts please follow the below steps:
#
# Click on the Menu icon of the browser, it opens up a list of options.
# Click on the “Options ”, it opens up the settings page,
# Here click on the “Privacy & Security” options listed on the left hand side of the page.
# Scroll down the page to the “Permission” section .
# Here click on the “Settings” tab of the Notification option.
# A pop up will open with all listed sites, select the option “ALLOW“, for the respective site under the status head to allow the notification.
# Once the changes is done, click on the “Save Changes” option to save the changes.
#
#
#
#
#
#
#
#  Notifications
#
#
#
#
#
#
#
# Clear All
#
#
# No Notifications
#
#
# Search search
# Menu menu clear
#  search
#
#
# clear
#
#
#
# Recent Searches
#
#
#
# Popular Search
#
#
#
#
#
# clear
#
#
# Also available in:
#
#
# हिन्दी
#
#
# ಕನ್ನಡ
#
#
# മലയാളം
#
#
# தமிழ்
#
#
# తెలుగు
#
#
#
#
#
#
#
# News
#
#
# Car News
#
#
# Bike News
#
#
# Spy Shots
#
#
# Motorsports
#
#
# Auto Shows
#
#
# Green Vehicles
#
#
# Commercial Vehicles
#
#
#
#
# Reviews
#
#
# Car Reviews
#
#
# Bike Reviews
#
#
# Comparisons
#
#
# Travelogues
#
#
# Experience Drives
#
#
# Experience Rides
#
#
#
#
# New Cars / Bikes
#
#
# Search Cars
#
#
# Search Car Tyres
#
#
# Search Bikes
#
# Search Cycles
#
# New Launches
#
#
# Car Dealers
#
#
# Bike Dealers
#
#
# CSD Cars Price List
#
#
# Car Loan EMI Calculator
#
#
# Bike Loan EMI Calculator
#
#
# Car Helpline Numbers
#
#
# RTO Vehicle Registration
#
#
#
#
# Gallery
#
#
# Videos
#
#
# Wallpapers
#
#
# Car and Bike Photos
#
#
#
#
# More
#
#
# How-to / Advice
#
#
# Car Modifications
#
#
# Bike Modifications
#
#
# Off-beat / Interesting
#
#
# CNG Price Today
#
#
# LPG Price Today
#
#
# Petrol Price Today
#
#
# Diesel Price Today
#
#
#
#
#
#
#
#
#
#
#  Trending
#
# Photos photo_library
#
#
# Videos play_circle_outline
#
#
# Cars directions_car
#
#
# Bikes motorcycle
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home »
# RTO Vehicle Registration Details »
# Maharashtra »
# MH-03
#
#
#
#
#
#
# Vehicle Registration Details
#
#
# RTO Phone Number and Email ID to contact the department. If you wish to search for any other registration details, enter the vehicle number in the search box below. The DriveSpark RTO Database covers details of Regional Transport Offices in all States and Union Territories in India.
#
#
#
#
#
#
# MH Registration - Regional Transport Office (RTO) MH-03
#
#
#
#
#
# NumberMH-03
#
# CityMumbai (East) - Ghatkopar
#
# StateMaharashtra
#
# Phone+(91)-22-24036479 / 24036221
#
# Emailmh03@mahatranscom.in
#
# Address3rd Floor, Wadala Truck Terminals, Wadala, Mumbai - 400037
#
#
#
#
#
#
# Search Another Vehicle Registration Number
#
# Find
#
#
#
#
#
#
#
#
#
#
#
#
#
# POPULAR CARS IN INDIA
#
#
#
#
#
#
#
#
#
# Hyundai Grand i10
#  4.98 - 7.91 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Volkswagen Polo 2011
#  5.71 - 9.72 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Hyundai Elite i20
#  5.43 - 9.23 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Swift
#  Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Ford Figo
#  5.50 - 8.46 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Renault Kwid
#  2.67 - 4.64 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Baleno
#  5.58 - 8.76 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Tata Tiago
#  3.35 - 6.97 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Alto 800
#  2.63 - 3.90 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Ignis
#  4.94 - 8.12 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Honda Amaze
#  5.54 - 8.37 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Honda City
#  8.77 - 14.53 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Fiat Linea
#  7.19 - 10 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Volkswagen Vento
#  8.64 - 14.34 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Ciaz
#  8.19 - 11.98 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Dzire
#  5.60 - 9.53 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Hyundai Verna
#  8.18 - 14.08 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Ford Aspire
#  5.49 - 8.34 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Volkswagen Ameo
#  5.50 - 10 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Skoda Rapid
#  6.99 - 14.26 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Mahindra Bolero
#  7.61 - 9.42 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Renault Duster
#  8 - 13.24 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Tata Safari Storme
#  10.97 - 16.35 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Ford EcoSport
#  7.83 - 11.90 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Nissan Terrano
#  10 - 14.65 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Mahindra Scorpio
#  10.24 - 18.15 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Mahindra XUV500
#  12.37 - 20.11 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Hyundai Creta
#  9.29 - 14.55 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Maruti Suzuki Vitara Brezza
#  7.41 - 10.60 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
# Tata Hexa
#  12.99 - 18.65 Lakh
#
#
#
#
#
#
# Price
#
#
#
#
# 
# EMI
#
#
#
#
#
#
#
#
#
#
#
#
# LATEST NEWS
#
#
#
#
#
#
#
#
#
# 2022 Maruti Suzuki Baleno Brochure Leaked: Variant-Wise Feature List Revealed
#
#
# calendar_today 21 February 2022
# person Athul
#
# The brochure of the upcoming 2022 Maruti Suzuki Baleno has been leaked online and the Leaked brochure reveals much more than basic specifications.
# Read more
#
#
#
#
#
#
#
#
#
#
# DriveSpark Exclusive: Citroen C3 Spotted Testing In Andhra Pradesh
#
#
# calendar_today 21 February 2022
# person Athul
#
# The upcoming 2022 Citroen C3 sub-4m SUV has been spotted testing once again in India with heavy camouflage. This time, the upcoming Citroen C3 sub-4m SUV was spotted testing in Andhra Pradesh.
# Read more
#
#
#
#
#
#
#
#
#
#
# 2022 Audi A8 Unveiled: Comes With Hybrid Diesel, Plug-In Hybrid & A 571bhp V8
#
#
# calendar_today 20 February 2022
# person Athul
#
# Audi has taken the wraps off the new facelifted version of the Audi A8 luxury sedan. The latest iteration of the luxury sedan from the German automaker now comes with a super-efficient 48-volt mild-hybrid powertrain as well.
# Read more
#
#
#
#
#
#
#
#
#
#
# Porsche 718 Cayman GTS 4.0 Vs BMW M4 Competition xDrive: Specs Comparo
#
#
# calendar_today 19 February 2022
# person Athul
#
# BMW and Porsche recently launched their respective sports car in India. While Munich-based German automaker launched the M4 Competition xDrive, the Stuttgart-based automaker launched the 718 Cayman GTS 4.0.
# Read more
#
#
#
#
#
#
#
#
#
#
# 2022 Royal Enfield Scram 411 To Be Launched In March: Likely To Be Positioned Below Himalayan
#
#
# calendar_today 18 February 2022
# person Athul
#
# Royal Enfield will soon launch the much-awaited Royal Enfield Scram 411 in India. According to a recent teaser, the Himalayan based scrambler-style motorcycle could be launched on 7th March 2022.
# Read more
#
#
#
#
#
#
#
#
#
#
# New Safety Rules For Children On Two-Wheelers: Are They Really Practical?
#
#
# calendar_today 16 February 2022
# person Stephen Gershom
#
# New safety rules for children on two-wheelers have been put in place. The new rule mandates the use of helmets and a safety harness for children who are taken on a two-wheeler ride. It also limits the speed of the vehicle
# Read more
#
#
#
#
#
#
#
#
#
#
# Ather Energy Partners With Gujarat Titans: Signs Multi-Year Partnership
#
#
# calendar_today 15 February 2022
# person Athul
#
# Ather Energy has partnered with Gujrat Titans as their teams principal partner for the upcoming 2022 IPL season. Moreover, Ather Energy has signed a multi-year contract with the Gujarat Titans team.
# Read more
#
#
#
#
#
#
#
#
#
#
# 2022 KTM 390 Adventure Arrives At Dealership: Comes with New Colour Options & More
#
#
# calendar_today 14 February 2022
# person Athul
#
# 2022 KTM 390 Adventure arrives at dealerships ahead of the launch in the country and the new models come with plenty of subtle improvements over its predecessor. So, expect KTM to launch the 2022 KTM 390 Adventure in a few days.
# Read more
#
#
# Read all news
#
#
#
#
#
#
# BEST CARS IN INDIA
#
#
#
# Best HatchbacksBest SedansBest SUVsBest MPVsBest Luxury CarsBest Diesel CarsBest Petrol CarsBest Automatic CarsBest CNG CarsBest Diesel HatchbacksBest Petrol HatchbacksBest Diesel SedansBest Petrol SedansBest Diesel SUVsBest Petrol SUVsBest Diesel Automatic CarsBest Petrol Automatic CarsBest 1000cc CarsBest 1200cc CarsBest 1600cc CarsBest Pickup TrucksBest Cars For WomenBest Cars For MenBest Cars For FamilyBest Cars For TeensBest Resale Value CarsBest Cars For CabBest Hybrid CarsBest Cars For Long DriveBest Cars For Indian RoadsBest JeepsBest Cars For VIPsBest Low Maintenance CarsBest Sports CarsBest Super CarsBest Convertible CarsBest Compact SUVsBest Off-Road CarsBest Electric CarsBest Safe CarsBS6 Cars in India
#
#
#
#
#
#
#
# Best Mileage Cars in India
#
#
#
# Best Mileage CarsBest Mileage Cars 0-3 LakhsBest Mileage Cars 4-6 LakhsBest Mileage Cars 6-8 LakhsBest Mileage Cars 8-10 LakhsBest Mileage Cars 10-12 LakhsBest Mileage Cars 15-20 LakhsBest Mileage Petrol CarsBest Mileage Diesel Cars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DriveSpark in Other Languages
#
# हिन्दी
# ಕನ್ನಡ
# മലയാളം
# தமிழ்
# తెలుగు
#
#
#
# Explore DriveSpark
#
#  Best SUVs
#  Best MPVs
#  Best Petrol Cars
#  Best Diesel Cars
#  Best Sedan Cars
#  Best Luxury Cars
#  Best Mileage Cars
#  Best Automatic Cars
#  Best Hatchback Cars
#
#
#
# Other Greynium Sites
#
# Filmibeat
# Boldsky
# Coupons
# Gizbot
# Goodreturns
# Native Planet
# Careerindia
# Clickin
#
#
#
# Follow DriveSpark
#
#
#
#
#
#
#
#
#
# About Us | Terms of Service | Privacy Policy | RSS | Contact Us | Site Feedback | Sitemap | Cookie Policy
#
# ©  Greynium Information Technologies Pvt. Ltd. All Rights Reserved.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get Instant News Updates
#
# Enable
#
# x
#
#
#
#
#  Notification Settings
# X
#
#
# Time Settings
#
#
#
#
#
#
#
#
# Don't Block
#
#
#
#
#
#
#
#
#
# Block for 8 hours
#
#
#
#
#
#
#
#
#
# Block for 12 hours
#
#
#
#
#
#
#
#
#
# Block for 24 hours
#
#
#
#
#
#
#
#
#
#
# Dont send alerts during
#
# 1 am
# 2 am
# 3 am
# 4 am
# 5 am
# 6 am
# 7 am
# 8 am
# 9 am
# 10 am
# 11 am
# 12 pm
# 1 pm
# 2 pm
# 3 pm
# 4 pm
# 5 pm
# 6 pm
# 7 pm
# 8 pm
# 9 pm
# 10 pm
# 11 pm
# 12 am
#
# to
#
# 1 am
# 2 am
# 3 am
# 4 am
# 5 am
# 6 am
# 7 am
# 8 am
# 9 am
# 10 am
# 11 am
# 12 pm
# 1 pm
# 2 pm
# 3 pm
# 4 pm
# 5 pm
# 6 pm
# 7 pm
# 8 pm
# 9 pm
# 10 pm
# 11 pm
# 12 am
#
#
#
#
#
#
#
#
#
#
#
# Switch Off
#
#
#
#
#
#
#
#
#
# Clear My notification inbox
#
#
#
# Done
#
#
#
#
#  Clear Notification
# X
#
# Do you want to clear all the notifications from your inbox?
#
#
# Yes No
#
#
#
# Settings
# X
#
#
#
#
#
#
#
# 0
#
# No New Notifications
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please select your city

# %%
# Plagirsim check between text and Sub-String

def check1(res1, sub_str):
    if (res1.find(sub_str) == -1):
        print("Plagiarism not found in First Website ")

    else:
        print("Plagiarism found in First Website ",result1)
def check2(res2, sub_str):
    if (res2.find(sub_str) == -1):
        print("Plagiarism not found in Second Website")

    else:
        print("Plagiarism found in Second Website ",result2)
# driver code

sub_str= query
check1(res1, sub_str)
check2(res2, sub_str)
# Out:
# Plagiarism not found in First Website
# Plagiarism not found in Second Website
